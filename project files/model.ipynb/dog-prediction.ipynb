# %%
import os
import shutil
import sys
import pandas as pd

# %%
[]
dataset_dir = r'C:\Users\Bhavani\Downloads\dog\Dog Breed Identification using Transfer Learning\dog-breed-identification\train'
labels = pd.read_csv(r'C:\Users\Bhavani\Downloads\dog\Dog Breed Identification using Transfer Learning\dog-breed-identification\labels.csv')

# %%
[]
import os

def make_dir(x):
    if os.path.exists(x)==False:
        os.makedirs (x)
base_dir = './subset'
make_dir (base_dir)

# %%
[]
train_dir = os.path.join(base_dir, 'train')
make_dir(train_dir)

# %%
[]
breeds = labels.breed.unique()
for breed in breeds:
    #Make folder for each breed
    _= os.path.join(train_dir, breed)
    make_dir(_)

# %%
#Copy images to the corresponding folders
images = labels [labels.breed == breed] ['id']
for image in images:
    source = os.path.join(dataset_dir, f'{image}.jpg')
    destination = os.path.join(train_dir, breed,f' {image}.jpg')
    shutil.copyfile (source, destination)

# %%
#import image datagenerator Library
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2,zoom_range=0.2,horizontal_flip=True)

# %%
datagen = ImageDataGenerator()
generator = datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224), # Adjust target size as needed
    batch_size=32,
    class_mode='categorical',
    shuffle=False # Ensure order is maintained for class indices
)
# Out:
# Found 76 images belonging to 120 classes.

# %%
test_datagen = ImageDataGenerator (rescale=1./255)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense
from tensorflow.keras.activations import softmax

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
[]
Image_size=[224,224]

# %%
[]
sol=VGG19(input_shape=Image_size + [3], weights='imagenet', include_top = False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 151s 2us/step

# %%
[]
for i in sol.layers:
    i.trainable = False

# %%
[]
y=Flatten() (sol.output)

# %%
from tensorflow.keras import activations
from tensorflow.keras.layers import Dense
final = Dense(20, activation='softmax')(y)

# %%
model = VGG19(...)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574710816/574710816 ━━━━━━━━━━━━━━━━━━━━ 943s 2us/step

# %%
metrics=['accuracy']

# %%
[] VGG1919_model.fit(generator, epochs = 6)
# Out:
#   Cell In[71], line 1
#     [] VGG1919_model.fit(generator, epochs = 6)
#        ^
# SyntaxError: invalid syntax

# %%
[]
vgg19_model.save("dogbreed.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 2
#       1 []
# ----> 2 vgg19_model.save("dogbreed.h5")
#
# NameError: name 'vgg19_model' is not defined

# %%
import numpy as np
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
# Out:
#   Cell In[59], line 1
#     1 import numpy as np
#       ^
# SyntaxError: invalid syntax

# %%
[]
img_path='/content/test/000621fb3cbb32d8935728e48679680e.jpg'

# %%
img load_img(img_path, target_size=(224, 224))
x= img_to_array(img)
x = preprocess_input(x)
preds = vgg19_model.predict(np.array([x]))

# %%
[] class_names=['affenpinscher', 'beagle', 'appenzeller', 'basset', 'bluetick", "boxer', 'cairn", "doberman', 'german_shepherd', 'golden_retriever", "kelpie', 'komondor', 'leonberg']

# %%
[] class_names [np.argmax(preds)]
